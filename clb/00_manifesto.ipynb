# %% [markdown]
# # とにかくやれ — ブラウザとAIで成果を手に入れる薄い本\n\nこのNotebookは「とにかくやれ」の実践スケルトン。\n

# %% [markdown]
# ## ルール\n\n説明しすぎない。まず頼む。動かす。成果を見る。ダメなら直す。\n

# %%
# TODO: ChatGPTに頼む → 動かす → 結果を見る → 直す\n
